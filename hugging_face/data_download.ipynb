# %%
# from datasets import load_dataset
from pprint import pprint
import json

# %%
# ds_7dayWorkout_900 = load_dataset("CristiD7/Comprehensive_7Day_Workout_Plans")
# ds_plannerStudy_628 = load_dataset("johaanm/planner3")
ds_workouts_101 = load_dataset("Kolibri753/generate-workouts")

ds_detailedExercise_1K  = load_dataset("rbgo/nutrition-exercise-planner")
# ds_productivityQ_45K = load_dataset("CholePuri/Productivity_Related_Questions")
# ds = load_dataset("trongkami/habit-productivity-life-coach-dataset")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# c:\Users\ESLAM\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:130: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ESLAM\.cache\huggingface\hub\datasets--rbgo--nutrition-exercise-planner. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
# pprint(ds_workouts_101["train"][:5])
pprint(
    {
        "\\n\\n**Exercise Recommendations**:\\n\\n1. **Warm-up (5 minutes)**: Start with a 5-minute brisk walk to get your blood flowing.\\n\\n2. **Core Strengthening (3 days a week)**:\\n   - a. Planks: Hold for 30 seconds, followed by a 15-second rest.\\n   - b. Bird-Dogs: 3 sets of 10 reps per side with a 30-second rest.\\n   - c. Supermans: 3 sets of 12 reps with a 30-second rest.\\n\\n3. **Back and Shoulder Flexibility (2 days a week)**:\\n   - a. Cat-Cow Stretch: Perform for 2 minutes.\\n   - b. Child\'s Pose: Hold for 1 minute.\\n   - c. Shoulder Blade Squeeze: 3 sets of 12 reps with a 30-second rest.\\n\\n4. **Posture Awareness (Daily)**: Practice good posture while sitting at your desk. Sit up straight, keep your feet flat on the floor, and adjust your chair and computer to proper ergonomic positions.\\n\\n5. **Walking Breaks (Daily)**: Take a 5-minute walk break every hour to alleviate back strain.\\n\\n6. **Cool Down and Stretching (5 minutes)**: After your workout, spend 5 minutes stretching your back, shoulders, and chest muscles.\\n\\n7. **Rest Days (2 days a week)**: Allow your body to recover. No strenuous exercise on these days.\\n\\n**Total Workout Time**: 20-30 minutes for the exercise routine.\\n\\n**Rest**: 15 seconds during core exercises, 30 seconds during back and shoulder flexibility exercises.\\n\\nThis plan focuses on core strength and flexibility, which are crucial for improving posture and alleviating back pain. Consistency is key, so make an effort to maintain proper posture throughout the day and take regular walking breaks."
    }
)
# pprint(ds_detailedExercise_1K["train"][:1])
# Out:
# {'\\n\\n**Exercise Recommendations**:\\n\\n1. **Warm-up (5 minutes)**: Start '
#  'with a 5-minute brisk walk to get your blood flowing.\\n\\n2. **Core '
#  'Strengthening (3 days a week)**:\\n   - a. Planks: Hold for 30 seconds, '
#  'followed by a 15-second rest.\\n   - b. Bird-Dogs: 3 sets of 10 reps per '
#  'side with a 30-second rest.\\n   - c. Supermans: 3 sets of 12 reps with a '
#  '30-second rest.\\n\\n3. **Back and Shoulder Flexibility (2 days a '
#  "week)**:\\n   - a. Cat-Cow Stretch: Perform for 2 minutes.\\n   - b. Child's "
#  'Pose: Hold for 1 minute.\\n   - c. Shoulder Blade Squeeze: 3 sets of 12 reps '
#  'with a 30-second rest.\\n\\n4. **Posture Awareness (Daily)**: Practice good '
#  'posture while sitting at your desk. Sit up straight, keep your feet flat on '
#  'the floor, and adjust your chair and computer to proper ergonomic '
#  'positions.\\n\\n5. **Walking Breaks (Daily)**: Take a 5-minute walk break '
# ...

# %% [markdown]
# **Warm-up (5 minutes)**: Start '
#  'with a 5-minute brisk walk to get your blood flowing.\\n\\n2.
# **CoreStrengthening (3 days a week)**:\\n
#    - a. Planks: Hold for 30 seconds, 'followed by a 15-second rest.\\n
#    - b. Bird-Dogs: 3 sets of 10 reps per side with a 30-second rest.\\n
#    - c. Supermans: 3 sets of 12 reps with a 30-second rest.\\n\\n3.
# **Back and Shoulder Flexibility (2 days a "week)**:\\n
#    - a. Cat-Cow Stretch: Perform for 2 minutes.\\n
#    - b. Child's "'Pose: Hold for 1 minute.\\n
#    - c. Shoulder Blade Squeeze: 3 sets of 12 reps 'with a 30-second rest.\\n\\n4.
# **Back and Shoulder Flexibility (2 days a "week)**:\\n
#    - a. Cat-Cow Stretch: Perform for 2 minutes.\\n
#    - b. Child's "'Pose: Hold for 1 minute.\\n
#    - c. Shoulder Blade Squeeze: 3 sets of 12 reps with a 30-second rest.\\n\\n4.
#
# **Walking Breaks (Daily)**:
#    - Take a 5-minute walk break every hour to alleviate back strain.\\n\\n6.
# **Cool Down and Stretching (5 'minutes)**:
#  After your workout, spend 5 minutes stretching your back, '
#  'shoulders, and chest muscles.\\n\\n7.
# **Rest Days (2 days a week)**: Allow '
#  'your body to recover. No strenuous exercise on these days.\\n\\n
# **Total Workout Time**: 20-30 minutes for the exercise routine.\\n\\n
# **Rest**: 15 '
#  'seconds during core exercises, 30 seconds during back and shoulder '
#  'flexibility exercises.\\n\\n

# %%
# print(ds_workouts_101)
# print(ds_7dayWorkout_900)
print(ds_plannerStudy_628)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['output', 'instruction', 'input'],
#         num_rows: 628
#     })
# })

# %%
# Save 7dayWorkout_900
# ds_7dayWorkout_900["train"].to_json(
#     "datasets/7dayWorkout_900.json", orient="records", lines=True
# )

# Save plannerStudy_628
ds_plannerStudy_628["train"].to_json(
    "Original datasets/plannerStudy_628.json", orient="records", lines=True
)

# # Save workouts_101
# ds_workouts_101["train"].to_json(
#     "datasets/workouts_101.json", orient="records", lines=True
# )
# Out:
# Creating json from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 5469274

# %%
pprint(ds_plannerStudy_628["train"][0])  # Print one record nicely
# Out:
# {'Context': 'I am a 21-year-old male with a height of 180 cm and a weight of '
#             '55 kg. My primary goal is endurance, and I aim to reach a target '
#             'weight of 45 kg. I am a beginner at the gym. Can you create a '
#             '7-day workout plan for me?',
#  'Response': 'Monday:\n'
#              '- Russian Twists: 3 sets of 20 reps\n'
#              '- Pull-ups: 3 sets of 10 reps\n'
#              '- Squats: 3 sets of 10 reps\n'
#              'Tuesday:\n'
#              '- Burpees: 3 sets of 6 reps\n'
#              '- Running: 3 sets of 20 reps\n'
#              '- Shoulder Press: 3 sets of 20 reps\n'
#              'Wednesday:\n'
#              '- Rest Day\n'
#              'Thursday:\n'
#              '- Planks: 3 sets of 6 reps\n'
#              '- Tricep Dips: 3 sets of 15 reps\n'
#              '- Shoulder Press: 3 sets of 8 reps\n'
#              'Friday:\n'
#              '- Walking: 3 sets of 10 reps\n'
# ...

# %%
# sample = ds_7dayWorkout_900["train"][:5]  
# print(json.dumps(sample, indent=4, ensure_ascii=False))
# Out:
# {
#     "Context": [
#         "I am a 21-year-old male with a height of 180 cm and a weight of 55 kg. My primary goal is endurance, and I aim to reach a target weight of 45 kg. I am a beginner at the gym. Can you create a 7-day workout plan for me?",
#         "I am a 45-year-old male with a height of 200 cm and a weight of 59 kg. My primary goal is weight loss, and I aim to reach a target weight of 54 kg. I am a intermediate at the gym. Can you create a 7-day workout plan for me?",
#         "I am a 44-year-old female with a height of 194 cm and a weight of 55 kg. My primary goal is weight loss, and I aim to reach a target weight of 50 kg. I am a advanced at the gym. Can you create a 7-day workout plan for me?",
#         "I am a 52-year-old female with a height of 196 cm and a weight of 73 kg. My primary goal is weight loss, and I aim to reach a target weight of 68 kg. I am a intermediate at the gym. Can you create a 7-day workout plan for me?",
# ...
